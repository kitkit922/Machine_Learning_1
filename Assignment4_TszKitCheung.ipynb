# %% [markdown]
# <a href="https://colab.research.google.com/github/kitkit922/Machine_Learning_1/blob/main/Assignment4_TszKitCheung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Tsz Kit Cheung (Kevin) N01555831 Assignment 4

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Tsz Kit Cheung N01555831 ITE 5310 Assignment 4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/L5/Assign04/Mall_Customers.csv')

# %%
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
Xm = data[['Annual Income (k$)','Spending Score (1-100)']].to_numpy()

# %% [markdown]
# #Perform DBSCAN clustering
# testing with Epsilon = 5, 10, 20
# testing with sample size = 3, 5, 10

# %%
# Epsilon = 5, min sample = 3

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=5, min_samples = 3)
y_dbscan = dbscan.fit_predict(Xm)

plt.figure(figsize = (12,8))
sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
plt.title('DBSCAN Cluster, Epsilon = 5, minimum sample = 3', fontsize = 25)
plt.xlabel('Annual Income (k$)', fontsize = 15)
plt.ylabel('Spending Score (1-100)', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
# Epsilon = 10, min sample = 3

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=10, min_samples = 3)
y_dbscan = dbscan.fit_predict(Xm)

plt.figure(figsize = (12,8))
sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
plt.title('DBSCAN Cluster, Epsilon = 10, minimum sample = 3', fontsize = 25)
plt.xlabel('Annual Income (k$)', fontsize = 15)
plt.ylabel('Spending Score (1-100)', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
# Epsilon = 20, min sample = 3

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=20, min_samples = 3)
y_dbscan = dbscan.fit_predict(Xm)

plt.figure(figsize = (12,8))
sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
plt.title('DBSCAN Cluster, Epsilon = 20, minimum sample = 3', fontsize = 25)
plt.xlabel('Annual Income (k$)', fontsize = 15)
plt.ylabel('Spending Score (1-100)', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
# Epsilon = 10, min sample = 5

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=10, min_samples = 5)
y_dbscan = dbscan.fit_predict(Xm)

plt.figure(figsize = (12,8))
sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
plt.title('DBSCAN Cluster, Epsilon = 10, minimum sample = 5', fontsize = 25)
plt.xlabel('Annual Income (k$)', fontsize = 15)
plt.ylabel('Spending Score (1-100)', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
# Epsilon = 10, min sample = 10

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=10, min_samples = 10)
y_dbscan = dbscan.fit_predict(Xm)

plt.figure(figsize = (12,8))
sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
plt.title('DBSCAN Cluster, Epsilon = 10, minimum sample = 10', fontsize = 25)
plt.xlabel('Annual Income (k$)', fontsize = 15)
plt.ylabel('Spending Score (1-100)', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
# Epsilon = 10, min sample = 20

from sklearn.cluster import DBSCAN
dbscan = DBSCAN(eps=10, min_samples = 20)
y_dbscan = dbscan.fit_predict(Xm)

plt.figure(figsize = (12,8))
sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
plt.title('DBSCAN Cluster, Epsilon = 10, minimum sample = 20', fontsize = 25)
plt.xlabel('Annual Income (k$)', fontsize = 15)
plt.ylabel('Spending Score (1-100)', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# # By simple comparison, Epsilon = 10, min sample = 5 is the best match

# %% [markdown]
# # Evaluate clustering performance using CH-Index and Silhouette score. (For Epsilon 1 - 20 and min samples 5)

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score

CHlist = []
SSlist = []

max_ch = 0
max_ss = 0
max_ch_n = 0
max_ss_n = 0


for i in range (1,51):
  dbscan = DBSCAN(eps=i, min_samples = 5)
  y_dbscan = dbscan.fit_predict(Xm)

  # calinski_harabasz_score
  try:
    chscore = calinski_harabasz_score(Xm,y_dbscan)
    CHlist.append(chscore)
    print(f'Calinski Harabasz Score(eps = {i}) : {chscore}')

    # silhouette_score
    ssscore = silhouette_score(Xm,y_dbscan)
    SSlist.append(ssscore)
    print(f'Silhouette Score(eps = {i}) : {ssscore}')
    print('')
  except:
    pass

#find Calinski Harabasz Score max
for i, element in enumerate(CHlist):
  if element > max_ch:
    max_ch = element
    max_ch_n = i
print(f'Max Calinski Harabasz Score: (eps = {max_ch_n + 2}) : {max_ch}')

#find Silhouette Score max
for i, element in enumerate(SSlist):
  if element > max_ss:
    max_ss = element
    max_ss_n = i
print(f'Max Silhouette Score: (eps = {max_ss_n + 2}) : {max_ss}')
# Out:
# Calinski Harabasz Score(eps = 2) : 0.22621059924152148
# Silhouette Score(eps = 2) : -0.3384933492468103
#
# Calinski Harabasz Score(eps = 3) : 0.9129688314069694
# Silhouette Score(eps = 3) : -0.2554528275053913
#
# Calinski Harabasz Score(eps = 4) : 4.974755605940909
# Silhouette Score(eps = 4) : -0.10103698779610991
#
# Calinski Harabasz Score(eps = 5) : 12.542026082219296
# Silhouette Score(eps = 5) : 0.1135163893571667
#
# Calinski Harabasz Score(eps = 6) : 14.43618957418093
# Silhouette Score(eps = 6) : 0.17302718791093943
#
# Calinski Harabasz Score(eps = 7) : 23.492392017974602
# Silhouette Score(eps = 7) : 0.2341227329782859
#
# Calinski Harabasz Score(eps = 8) : 37.41349958515138
# Silhouette Score(eps = 8) : 0.3550982050619174
#
# Calinski Harabasz Score(eps = 9) : 74.42339301737698
# Silhouette Score(eps = 9) : 0.43598431858196485
#
# Calinski Harabasz Score(eps = 10) : 77.7956966791007
# Silhouette Score(eps = 10) : 0.41249187303464097
#
# ...

# %% [markdown]
# Max Calinski Harabasz Score when epsilon (eps = 10)
# Max Silhouette Score when epsilon (eps = 9)

# %% [markdown]
# # Evaluate clustering performance using CH-Index and Silhouette score. (For Epsilon 10 and min samples = 1 - 50)

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score

CHlist = []
SSlist = []

max_ch = 0
max_ss = 0
max_ch_n = 0
max_ss_n = 0


for i in range (1,51):
  dbscan = DBSCAN(eps=10, min_samples = i)
  y_dbscan = dbscan.fit_predict(Xm)

  # calinski_harabasz_score
  try:
    chscore = calinski_harabasz_score(Xm,y_dbscan)
    CHlist.append(chscore)
    print(f'Calinski Harabasz Score(min_samples = {i}) : {chscore}')

    # silhouette_score
    ssscore = silhouette_score(Xm,y_dbscan)
    SSlist.append(ssscore)
    print(f'Silhouette Score(min_samples = {i}) : {ssscore}')
    print('')
  except:
    pass

#find Calinski Harabasz Score max
for i, element in enumerate(CHlist):
  if element > max_ch:
    max_ch = element
    max_ch_n = i
print(f'Max Calinski Harabasz Score: (min_samples = {max_ch_n + 1}) : {max_ch}')

#find Silhouette Score max
for i, element in enumerate(SSlist):
  if element > max_ss:
    max_ss = element
    max_ss_n = i
print(f'Max Silhouette Score: (min_samples = {max_ss_n + 1}) : {max_ss}')
# Out:
# Calinski Harabasz Score(min_samples = 1) : 36.075863557426466
# Silhouette Score(min_samples = 1) : 0.2880197198786086
#
# Calinski Harabasz Score(min_samples = 2) : 60.159221990351476
# Silhouette Score(min_samples = 2) : 0.32209816683577636
#
# Calinski Harabasz Score(min_samples = 3) : 86.46868433240198
# Silhouette Score(min_samples = 3) : 0.36270289706345077
#
# Calinski Harabasz Score(min_samples = 4) : 74.17246304214441
# Silhouette Score(min_samples = 4) : 0.39889488555584734
#
# Calinski Harabasz Score(min_samples = 5) : 77.7956966791007
# Silhouette Score(min_samples = 5) : 0.41249187303464097
#
# Calinski Harabasz Score(min_samples = 6) : 74.6490483647807
# Silhouette Score(min_samples = 6) : 0.40348780174661053
#
# Calinski Harabasz Score(min_samples = 7) : 78.44565135100619
# Silhouette Score(min_samples = 7) : 0.42084049577844984
#
# Calinski Harabasz Score(min_samples = 8) : 42.23595546342582
# Silhouette Score(min_samples = 8) : 0.36328873885121793
#
# ...

# %% [markdown]
# Max Calinski Harabasz Score when epsilon (min_samples = 3)
# Max Silhouette Score when epsilon (min_samples = 7)
# Min Samples I still use 5, both score is near the maximum

# %% [markdown]
# #Compare DBSCAN clustering with K-means
# I use 3 situations
# DBSCAN (For Epsilon 5 and min samples 5), cluster = 5
# DBSCAN (For Epsilon 10 and min samples 5), cluster = 4
# DBSCAN (For Epsilon 10 and min samples 12), cluster = 3

# %%
from sklearn.cluster import DBSCAN, KMeans
kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42)
dbscan = DBSCAN(eps=5, min_samples = 5)
y_kmeans = kmeans.fit_predict(Xm)
y_dbscan = dbscan.fit_predict(Xm)

fig,ax = plt.subplots(1,2,figsize=(12,6))
colorArray = [
    (0.2, 0.4, 0.6),
    (0.8, 0.1, 0.3),
    (0.5, 0.7, 0.2),
    (0.9, 0.5, 0.1),
    (0.3, 0.6, 0.9),
    (0.7, 0.2, 0.8),
    (0.1, 0.9, 0.4),
    (0.4, 0.8, 0.7),
    (0.6, 0.3, 0.5),
    (0.2, 0.5, 0.8)
]

for i in range(5):
  ax[0].scatter(Xm[y_kmeans == i, 0], Xm[y_kmeans == i, 1], s = 100, c = colorArray[i], label = f'Cluster {i+1}')
ax[0].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 150, c = 'yellow', label = 'Centroids')
ax[0].set_title('Clusters (n=5)', fontsize = 25)
ax[0].set_xlabel('Annual Income (k$)', fontsize = 15)
ax[0].set_ylabel('Spending Score (1-100)', fontsize = 15)
ax[0].legend(fontsize = 15)

sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
ax[1].set_title('Clusters (Epsilon 5 and min samples 5)', fontsize = 25)
ax[1].set_xlabel('Annual Income (k$)', fontsize = 15)
ax[1].set_ylabel('Spending Score (1-100)', fontsize = 15)
ax[1].legend(fontsize = 15)
plt.show()

# calinski_harabasz_score for kmeans
chscore_km = calinski_harabasz_score(Xm,y_kmeans)
print(f'Calinski Harabasz Score for K-means: {chscore_km}')

# silhouette_score for kmeans
ssscore_km = silhouette_score(Xm,y_kmeans)
print(f'Silhouette Score for K-means: {ssscore_km}')
print('')

# calinski_harabasz_score for dbscan
chscore_db = calinski_harabasz_score(Xm,y_dbscan)
print(f'Calinski Harabasz Score for DBSCAN: {chscore_db}')

# silhouette_score for dbscan
ssscore_db = silhouette_score(Xm,y_dbscan)
print(f'Silhouette Score for DBSCAN: {ssscore_db}')
print('')

if chscore_km > chscore_db:
  print('K-means has a higher calinski harabasz score')
else:
  print('DBSCAN has a higher calinski harabasz score')

if ssscore_km > ssscore_db:
  print('K-means has a higher Silhouette Score')
else:
  print('DBSCAN has a higher Silhouette Score')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-14-244f89e2209c>:22: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax[0].scatter(Xm[y_kmeans == i, 0], Xm[y_kmeans == i, 1], s = 100, c = colorArray[i], label = f'Cluster {i+1}')
# Calinski Harabasz Score for K-means: 247.35899338037282
# Silhouette Score for K-means: 0.553931997444648
#
# Calinski Harabasz Score for DBSCAN: 12.542026082219296
# Silhouette Score for DBSCAN: 0.1135163893571667
#
# K-means has a higher calinski harabasz score
# ...

# %%
from sklearn.cluster import DBSCAN, KMeans
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
dbscan = DBSCAN(eps=10, min_samples = 5)
y_kmeans = kmeans.fit_predict(Xm)
y_dbscan = dbscan.fit_predict(Xm)

fig,ax = plt.subplots(1,2,figsize=(12,6))
colorArray = [
    (0.2, 0.4, 0.6),
    (0.8, 0.1, 0.3),
    (0.5, 0.7, 0.2),
    (0.9, 0.5, 0.1),
    (0.3, 0.6, 0.9),
    (0.7, 0.2, 0.8),
    (0.1, 0.9, 0.4),
    (0.4, 0.8, 0.7),
    (0.6, 0.3, 0.5),
    (0.2, 0.5, 0.8)
]

for i in range(4):
  ax[0].scatter(Xm[y_kmeans == i, 0], Xm[y_kmeans == i, 1], s = 100, c = colorArray[i], label = f'Cluster {i+1}')
ax[0].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 150, c = 'yellow', label = 'Centroids')
ax[0].set_title('Clusters (n=4)', fontsize = 25)
ax[0].set_xlabel('Annual Income (k$)', fontsize = 15)
ax[0].set_ylabel('Spending Score (1-100)', fontsize = 15)
ax[0].legend(fontsize = 15)

sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
ax[1].set_title('Clusters (Epsilon 10 and min samples 5)', fontsize = 25)
ax[1].set_xlabel('Annual Income (k$)', fontsize = 15)
ax[1].set_ylabel('Spending Score (1-100)', fontsize = 15)
ax[1].legend(fontsize = 15)
plt.show()

# calinski_harabasz_score for kmeans
chscore_km = calinski_harabasz_score(Xm,y_kmeans)
print(f'Calinski Harabasz Score for K-means: {chscore_km}')

# silhouette_score for kmeans
ssscore_km = silhouette_score(Xm,y_kmeans)
print(f'Silhouette Score for K-means: {ssscore_km}')
print('')

# calinski_harabasz_score for dbscan
chscore_db = calinski_harabasz_score(Xm,y_dbscan)
print(f'Calinski Harabasz Score for DBSCAN: {chscore_db}')

# silhouette_score for dbscan
ssscore_db = silhouette_score(Xm,y_dbscan)
print(f'Silhouette Score for DBSCAN: {ssscore_db}')
print('')

if chscore_km > chscore_db:
  print('K-means has a higher calinski harabasz score')
else:
  print('DBSCAN has a higher calinski harabasz score')

if ssscore_km > ssscore_db:
  print('K-means has a higher Silhouette Score')
else:
  print('DBSCAN has a higher Silhouette Score')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-15-aacd176f7852>:22: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax[0].scatter(Xm[y_kmeans == i, 0], Xm[y_kmeans == i, 1], s = 100, c = colorArray[i], label = f'Cluster {i+1}')
# Calinski Harabasz Score for K-means: 174.0644335433684
# Silhouette Score for K-means: 0.4931963109249047
#
# Calinski Harabasz Score for DBSCAN: 77.7956966791007
# Silhouette Score for DBSCAN: 0.41249187303464097
#
# K-means has a higher calinski harabasz score
# ...

# %%
from sklearn.cluster import DBSCAN, KMeans
kmeans = KMeans(n_clusters = 3, init = 'k-means++', random_state = 42)
dbscan = DBSCAN(eps=10, min_samples = 12)
y_kmeans = kmeans.fit_predict(Xm)
y_dbscan = dbscan.fit_predict(Xm)

fig,ax = plt.subplots(1,2,figsize=(18,6))
colorArray = [
    (0.2, 0.4, 0.6),
    (0.8, 0.1, 0.3),
    (0.5, 0.7, 0.2),
    (0.9, 0.5, 0.1),
    (0.3, 0.6, 0.9),
    (0.7, 0.2, 0.8),
    (0.1, 0.9, 0.4),
    (0.4, 0.8, 0.7),
    (0.6, 0.3, 0.5),
    (0.2, 0.5, 0.8)
]

for i in range(3):
  ax[0].scatter(Xm[y_kmeans == i, 0], Xm[y_kmeans == i, 1], s = 100, c = colorArray[i], label = f'Cluster {i+1}')
ax[0].scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 150, c = 'yellow', label = 'Centroids')
ax[0].set_title('Clusters (n=3)', fontsize = 25)
ax[0].set_xlabel('Annual Income (k$)', fontsize = 15)
ax[0].set_ylabel('Spending Score (1-100)', fontsize = 15)
ax[0].legend(fontsize = 15)

sns.scatterplot(data = Xm, x = Xm[:,0], y = Xm[:,1], hue = y_dbscan, palette = 'Set1')
ax[1].set_title('Clusters (Epsilon 5 and min samples 12)', fontsize = 25)
ax[1].set_xlabel('Annual Income (k$)', fontsize = 15)
ax[1].set_ylabel('Spending Score (1-100)', fontsize = 15)
ax[1].legend(fontsize = 15)
plt.show()

# calinski_harabasz_score for kmeans
chscore_km = calinski_harabasz_score(Xm,y_kmeans)
print(f'Calinski Harabasz Score for K-means: {chscore_km}')

# silhouette_score for kmeans
ssscore_km = silhouette_score(Xm,y_kmeans)
print(f'Silhouette Score for K-means: {ssscore_km}')
print('')

# calinski_harabasz_score for dbscan
chscore_db = calinski_harabasz_score(Xm,y_dbscan)
print(f'Calinski Harabasz Score for DBSCAN: {chscore_db}')

# silhouette_score for dbscan
ssscore_db = silhouette_score(Xm,y_dbscan)
print(f'Silhouette Score for DBSCAN: {ssscore_db}')
print('')

if chscore_km > chscore_db:
  print('K-means has a higher calinski harabasz score')
else:
  print('DBSCAN has a higher calinski harabasz score')

if ssscore_km > ssscore_db:
  print('K-means has a higher Silhouette Score')
else:
  print('DBSCAN has a higher Silhouette Score')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-16-4a35b2c84d36>:22: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax[0].scatter(Xm[y_kmeans == i, 0], Xm[y_kmeans == i, 1], s = 100, c = colorArray[i], label = f'Cluster {i+1}')
# Calinski Harabasz Score for K-means: 151.5570090006799
# Silhouette Score for K-means: 0.46761358158775435
#
# Calinski Harabasz Score for DBSCAN: 19.154799651503534
# Silhouette Score for DBSCAN: 0.22386059994379756
#
# K-means has a higher calinski harabasz score
# ...

# %% [markdown]
# #K-means has a better score then DBSCAN in geenral. IN DBSCAN, it can detect for outliers and hence the cluster graph to be more diverse. The main purpose of DBSCAN is not divide all datapoints into defined number of clusters. The Calinski Harabasz Score and Silhouette Score is a better fit for K-Means approach and the Hierarchical clustering approach.
